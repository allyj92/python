# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel("some numbers")
plt.show()

# %%
t = np.arange(0.,5.,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %%
x= np.linspace(-np.pi,np.pi,256,endpoint=True)

# %%
C,S=np.cos(x),np.sin(x)

# %%
plt1 = plt.plot(x,C)
plt2 = plt.plot(x,S)
print(plt1)
print(plt2)
plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x000001B0784963D0>]
# [<matplotlib.lines.Line2D object at 0x000001B07872AE20>]

# %%
fig1 =plt.figure(1)
plt1 = plt.plot(x,C)
fig2 = plt.figure(2)
plt2 = plt.plot(x,S)
print(plt1,plt2)
print(fig1, fig2)

plt.show()
# Out:
# [<matplotlib.lines.Line2D object at 0x000001B0784A0550>] [<matplotlib.lines.Line2D object at 0x000001B0790CA760>]
# Figure(432x288) Figure(432x288)

# %%
# %matplotlib inline
plt.plot([1,2,3,4])
plt.ylabel(["some numbers"])
plt.show()

# %%
import seaborn as sns

# %%
x = np.linspace(0,10,1000)

# %%
y=np.power(x,2)
plt.plot(x,y)

# %%
plt.plot([1,2,3,4],'ro')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
x1 = [1,2,3,4,5]
y1 = [1,4,9,16,25]
x2 = [1,2,4,6,8]
y2 = [2,4,8,12,16]
plt.plot(x1,y1,'r')
plt.plot(x2,y2,'g')
plt.title("plot of y vs x")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.xlim(0.0,9.0)
plt.ylim(0.0,30.0)
plt.show()

# %%
x = [1,2,3]
y = [1,4,8]

# %%
plt.plot(x,y,color = 'green',linestyle='dashed',marker='o',markerfacecolor=
         'blue',markersize=12)
plt.show()

# %%
a = b = np.arange(0,3,.02)
c = np.exp(a)
d = c[::-1]

# %%
plt.plot(a,c,'k--',label="Model length")
plt.plot(a,d,'k:',label = 'Data length')
plt.plot(a,c+d,'k',label= 'Total message length')
plt.legend()
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y,linewidth=6.0)
plt.show()

# %%
#AXES 설명

# %%
f,ax = plt.subplots(1,1,figsize=(6,4))
print(f,ax)
# Out:
# Figure(432x288) AxesSubplot(0.125,0.125;0.775x0.755)

# %%
x = np.linspace(0,10,1000)
y = np.power(x,2)

# %%
ax.plot(x,y)
ax.set_xlim((1,5))
ax.set_ylim((0,30))
ax.set_xlabel('my x label')
ax.set_ylabel('my y label')
ax.set_title("plot title, including $`omegas$")
plt.tight_layout()
plt.show()
plt.savefig('line_plot_plus.pdf')

# %%
data=np.random.rand(10,2)
data
# Out:
# array([[0.39469828, 0.78927664],
#        [0.17119246, 0.48145049],
#        [0.98891991, 0.81107047],
#        [0.4457543 , 0.14879347],
#        [0.10392219, 0.00315677],
#        [0.8157659 , 0.95866842],
#        [0.27732846, 0.09285776],
#        [0.91574418, 0.65190548],
#        [0.4249231 , 0.27868864],
#        [0.82490751, 0.92439446]])

# %%
print(data.shape)
# Out:
# (10, 2)

# %%
plt.scatter(data[:,0],data[:,1])
plt.show()

# %%
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

# %%
plt.subplot(321)
plt.scatter(x,y,s=80,c=z,marker=">")
plt.show()

# %%
N = 5
menMeans= (20,35,30,35,27)
ind= np.arange(N)
plt.bar(ind,menMeans,width=0.8,color='r')
plt.show()

# %%
N = 5
menMeans= (20,35,30,35,27)
ind= np.arange(N)
plt.bar(ind,menMeans,width=1.0)
plt.show()

# %%
N = 5
menMeans= (20,35,30,35,27)
ind= np.arange(N)
plt.bar(ind,menMeans,width=0.5,color='r')
plt.show()

# %%
N = 5
menMeans = (20,35,30,35,27)
womenmeans=(25,32,34,20,25)
p1=plt.bar(ind+0.00, menMeans, width=0.33,color='r')
p2=plt.bar(ind+0.33,womenmeans,width=0.33,color='y')
plt.xlabel("The number of people")
plt.ylabel("Scores")
plt.title("Scores by group and gender")
plt.xticks(ind+0.33,('G1','G2','G3','G4','G5'))
plt.yticks(np.arange(0,81,10))
plt.legend(p1[0],p2[0],('Men','Women'))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 11>()
#       9 plt.xticks(ind+0.33,('G1','G2','G3','G4','G5'))
#      10 plt.yticks(np.arange(0,81,10))
# ---> 11 plt.legend(p1[0],p2[0],('Men','Women'))
#      13 plt.show()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2655, in legend(*args, **kwargs)
#    2653 @_copy_docstring_and_deprecators(Axes.legend)
#    2654 def legend(*args, **kwargs):
# -> 2655     return gca().legend(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:304, in Axes.legend(self, *args, **kwargs)
#     299 handles, labels, extra_args, kwargs = mlegend._parse_legend_args(
#     300         [self],
#     301         *args,
#     302         **kwargs)
#     303 if len(extra_args):
# --> 304     raise TypeError('legend only accepts two non-keyword arguments')
#     305 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306 self.legend_._remove_method = self._remove_legend
#
# TypeError: legend only accepts two non-keyword arguments

# %%
w_pop = np.array([5,30,45,40],dtype=np.float32)
m_pop = np.array([4,28,40,35],dtype=np.float32)
x =np.arange(4)

a = plt.barh(x,w_pop,color='r')
b = plt.barh(x,-m_pop)
plt.show()

# %%
data = [5,10,30,20,7,8,10,10]
label = ['A','B','C','D','E','F','G','H']
plt.pie(data,labels=label)
plt.show()

# %%
data = np.random.normal(5.0,3.0,1000)
plt.hist(data,bins=15)
plt.xlabel('data')
plt.show()

# %%
data = np.random.normal(5.0,3.0,1000)
plt.hist(data,facecolor='red',alpha=0.1,histtype='stepfilled')
bins=np.arange(-5.,16,1)
plt.hist(data,bins,histtype='stepfilled')
plt.xlabel('data')
plt.show()

# %%
data = np.random.randn(1000)
f,(ax1,ax2)=plt.subplots(1,2,figsize=(6,3))
print(ax1)
print(ax2)
ax1.hist(data,bins=30,normed=True,color='b')
ax2.hist(data,bins=30,normed=True,color='r')
plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.352273x0.755)
# AxesSubplot(0.547727,0.125;0.352273x0.755)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [101], in <cell line: 5>()
#       3 print(ax1)
#       4 print(ax2)
# ----> 5 ax1.hist(data,bins=30,normed=True,color='b')
#       6 ax2.hist(data,bins=30,normed=True,color='r')
#       7 plt.show()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
samp1 = np.random.normal(loc=0.,scale=1.,size=100)
samp2 = np.random.normal(loc=1.,scale=2.,size=100)
samp3 = np.random.normal(loc=0.3,scale=1.2,size=100)
plt.boxplot((samp1,samp2,samp3))
plt.show()

# %%
A = np.random.random((100,100))
plt.imshow(A)
plt.hot()
plt.colorbar()
plt.show()
plt.axis("off")
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("A.jpg")
print(type(img))
plt.imshow(img)
plt.hot()
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [123], in <cell line: 1>()
# ----> 1 img = mpimg.imread("A.jpg")
#       2 print(type(img))
#       3 plt.imshow(img)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py:1560, in imread(fname, format)
#    1558                 response = io.BytesIO(response.read())
#    1559             return imread(response, format=ext)
# -> 1560 with img_open(fname) as image:
#    1561     return (_pil_png_to_float_array(image)
#    1562             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1563             pil_to_array(image))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'A.jpg'

# %%
x = np.linspace(0,10,10)
sp1 = plt.subplot(2,2,1)
y = np.exp(x)
l1=plt.semilogy(x,y,color='m',linewidth=2)
lx = plt.xlabel("x")
ly = plt.ylabel("y")
t1 = plt.title("y=exp(x)")
print(sp1)

sp2 = plt.subplot(2,2,2)
y = x**-1.67
l1=plt.loglog(x,y)
lx = plt.xlabel("x")
ly = plt.ylabel("y")
t1 = plt.title("y=x$^{-5/3}$)")
print(sp2)
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.352273x0.343182)
# AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# C:\Temp\ipykernel_17232\3216215565.py:11: RuntimeWarning: divide by zero encountered in power
#   y = x**-1.67
